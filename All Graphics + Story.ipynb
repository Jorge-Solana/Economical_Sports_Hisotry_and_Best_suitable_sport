# %% [markdown]
# # The story of this project lies here

# %% [markdown]
# ###### IMPORTANT NOTE:
# ###### This project is based on the biggest earnings of each sport, not all the athletes have been taken into account, neither all the tournament's prices. Only the biggest fortunes of each sport in the last 30 years

# %% [markdown]
# We begin this project by looking for the 'difficult' sports and where the does the majority of sports lie, in term of the difficulty.
#
# This difficulty is measured by the calification of the 10 abilities in a scale from 1 to 10. The abilities are the following:
#
# - Endurance
# - Strength
# - Power
# - Speed
# - Agility
# - Flexibility
# - Nerve
# - Durability
# - Hand-Eye coordination
# - Analytical Aptitude

# %% [markdown]
# ![histogram.png](attachment:histogram.png)

# %% [markdown]
# This graph here is showing a frequency distribution of the sum of each idividual ability in each sport in this study.
#
# As we can observe, most of this sports are located between 45 and 55 out of 100, meaning that most the sports do not require having the abilities at its maximum exponent (for its mere practice, other thing is if somebdoy wants to excel in that particular sport).
#
# Also, it is important to mention, that the most 'complex' sport is just a little bit above 70, this means that despite of being complex is not impossible to practice.

# %% [markdown]
# ![difficulty_sports.png](attachment:difficulty_sports.png)

# %% [markdown]
# This graph is displayig the total sum of the ablities ratings of each individual sport.
#
# Here we can observe thta boxing is rated as the 'most complex' sport and fishing as 'the easiest one'.
#
# This ratings are just basad on a quantitative validation of 10 abilities going from 0 (requires nothing of thi ability) to 10 (requires the maximum of this ability).
#
# This graph is just showing the sum of all this quantitative ratings.

# %% [markdown]
# ### Once we have an overview of all the sports we have in our database we can take a look at the earnings of the sports

# %% [markdown]
# This daat is coming from anothes dataset. In this dataset we don't have all the 60 sports displayed in graphs showed before.
#
# In this new dataset we have 13 sports, this sports are the ones that have been the most profiteable in the last 30 years.
#
# (remember the note mentiones at the begining of this notebook)

# %% [markdown]
# ![sum_eranings.png](attachment:sum_eranings.png)

# %% [markdown]
# This graph is pretty straigth forward.
#
# We observe the total ammount of earnings (in million USD), of each sport in the last 30 years.
#
# It may surprise you that basketball has been the most profiteable sport in the last 30 years with a margin of 1000 million USD from the second one.
#
# Below basketball we have three sports pretty tied, this are boxing, soccer and golf. Boxing is pretty interesting (we are going to discuss it in the next graph), soccer is as expected with the very high salaries of the superathletes as Cristiano Ronaldo, Messi..., and golf has a good explanation; the gross ammount of this money belongs to Tiger Woods only, so if it wasn't for him, maybe even golf wouldn't be in the ranking.
#
# Cycling is the least profiteable sport in the last 30 years, with only 28 million USD, basically this fortune was made by Lance Amstrong

# %% [markdown]
# ![change_sports.png](attachment:change_sports.png)

# %% [markdown]
# In this graph we observe the yearly change of every sport before mentioned, money wise (million USD), in the last 30 years.
#
# This is a pretty interesting graph, were we can spend quite some time deconstructing each sport and understanding every up and down of each individual sport. For time-efficience means we are going only to explain te most significant and relevant changes.

# %% [markdown]
# ![just_boxing.png](attachment:just_boxing.png)

# %% [markdown]
# The most notorious line is the boxing one, going regularly up until 2010 where it started to increase and having an inmense increase (from 105M USD to 230M USD in just one year).
#
# How is this possible?
#
#    - From time to time, boxing has major fights which ara paid for over 100 million USD, and between 2015 and 2018, some of this ocurred more regularly than usual and having more media repercussion as usual.

# %% [markdown]
# ![change_sports_noboxing.png](attachment:change_sports_noboxing.png)

# %% [markdown]
# The rest of the lines are more regular throughout this last 30 years, all of them having an upwards tendency. We will talk about this later when we study every profiteable sport tendency.

# %% [markdown]
# ### After having an overall knowledge of how the ratings in each sports has changed in the last 30 years, we may want  know how they are going change in the next 10 year

# %% [markdown]
# We will do this study by doing a polynomic regression for each of the main sports.
#
# - For boxing and auto-racing, the r_squared is around 67%.
#
# - For golf, basketball, football and baseball, the r_squared lies around 80-85%.
#
# - Soccer and tennis has a higher r_squared, a little bit above 90%.
#
# - For the rest, moto-gp, cycling and hockey, the r_squared i super high!! But since we have so little values, the overfitting is enormous, so those polynomic regression do not represent a very accurate predictions.

# %% [markdown]
# ![graph_boxing.png](attachment:graph_boxing.png)

# %% [markdown]
# - Boxing: as we have seen before, in the last 5 years it has earned a lot of money, and its tendecy in the next 10 years is to continuie increasing up to more than 500 M USD in 2030

# %% [markdown]
# ![graph_football.png](attachment:graph_football.png)

# %% [markdown]
# - Footbal, american football, has almost the same prediction as basketball, growing in te next 10 years at a similar pace ending in 2030 close to 175 M USD

# %% [markdown]
# ![graph_auto_racing.png](attachment:graph_auto_racing.png)

# %% [markdown]
# - Auto racing: it was at its peak in 2005, although nowdays has gained a lot of popularity with Lewis Hamilton making huge amounts of money, the prediction for the next 20 years is for it to decresase a little bit, earning in 2030 20 M USD

# %% [markdown]
# ![graph_basket.png](attachment:graph_basket.png)

# %% [markdown]
# - Basketball is pretty straight forward, since 1990 it has been increasing and the prediction for the next 10 years is to keep growing as well, going up to 175M USD in 2030.

# %% [markdown]
# ![graph_tennis.png](attachment:graph_tennis.png)

# %% [markdown]
# - Tennis is pretty similar to baskeball, although it's growth is predicted to be bigger than basketball, earning in 2030 more than 200 M USD. This bigger growth is predicted due to the last 5 years of having enourmus salaries.

# %% [markdown]
# ![graph_baseball.png](attachment:graph_baseball.png)

# %% [markdown]
# - Baseball has an upwards tendency as well, but not as high as tennis or auto-racing. It is predicted in 2030 to increase up to a little bit lower of 120 M USD

# %% [markdown]
# ![graph_golf.png](attachment:graph_golf.png)

# %% [markdown]
# - Golfing is expected to have a huge decresing by 2030, after having its peak between 2005 and 2010 thanks to Tiger Woods, its decadence started

# %% [markdown]
# ![graph_hockey.png](attachment:graph_hockey.png)

# %% [markdown]
# ![graph_moto.png](attachment:graph_moto.png)

# %% [markdown]
# ![graph_cycling.png](attachment:graph_cycling.png)

# %% [markdown]
# - Moto GP, Cycling and Hockey. Because we have only few big earnings in this 30 year timeline, so just 3 points are not a very good neither accurate representation.

# %% [markdown]
# ### Since we have already took a look at the sports individually, in the last 30 years as well as a prediction for the next 10 years, let's have a look at the abilities

# %% [markdown]
# First we want to see how the abilities have changed in the last 30 years.
#
# But how are going to measure this?
#
# - By having the most profiteable sport for every year, we are going to take the most dominant ability for that sport (since the ratings are from 0 to 10 in 10 different abilities, one of the them has to be the most important one, even if only for 0.5 points), and we will plot it to see which ability has been the most profiteable in the last 30 years.

# %% [markdown]
# ![change_ability.png](attachment:change_ability.png)

# %% [markdown]
# This graph is related with the yearly change in sports earnings.
#
# Based on the premise explained above, the purpose of this graph is to show how the most dominant ability os a sport has changed (still money wise) in the last 30 years. This has been done by taking the most dominant ability of all the 9 most profiteable sports and then doing the same plot as before.
#
# We can clearly see that because of boxing, nerve has been clearly dminant in the last 5 years, before that, asgilty was above it throughout almost the rest of the years, except as well from 1990 and 1995.
#
# Analytical aptitude grew a lot in between 2005 and 2010 due to golfing and the ammout f fortune Tiger Woods was making.

# %% [markdown]
# ![ability_sports.png](attachment:ability_sports.png)

# %% [markdown]
# This graph show, for every unique ability, how it varies in every sport.
#
# (Note the different scales on each graph, not all are the same)
#
# What are the more relevant aspects we can acknowledge within this graph?
#
# - The ability which is more equally requiered in all the 9 sports is Analytical Aptitude, there are some which doesn't need that much of it, but the difference between those ones ans the ones who needs it the most is not big, less than 2 points.
#
# - On the other hand we can observe that there are some bilities which have a bigger dispersion throught the 9 sports. This are:
#     - Nerve: in boxing and auto racing is highly demanded (obviously), whereas for the rest of sports not that much
#     - Hand-Eye coordination: not that much needed for cycling and a lot needed for tennis (makes a lot of sense)
#     - Agility: auto-racing is obvios pretty low, as well as golf, physical static sports, quite the same for cycling
#     - Felixibility: for auto-racing and cycling there is not need for it.
#     - Power: all kind of at the same level except for auto-racing
#     - Speed: golf and auto racing below 2, still high in my opinion for this sports. the rest of the sports quite similar.

# %% [markdown]
# ### After we have seen how the abilites are distributed among the 9 sports, we want to evaluate each sport separated

# %% [markdown]
# ![9_sports.png](attachment:9_sports.png)

# %% [markdown]
# Let's deconstruct each sport:
#
# (note the different scales on each graph!)
#
# - Boxing : flexibility is not much needed. Speed, agility lie in the middle, it is needed but not that much, around 6/10, which is kind of surprising, you would've thought a boxer needs to be super agile. The most requiered abilities for a boxer are, nerve, endurance, power and durability. Basically a boxer needs to have great power and great stamina overall.
#
#
# - Ice Hockey : with durability as it man ability, it has all the abilities pretty equally calificated except for flexibility and nerve, which you don't really need that much (In ice hockey sometimes there are fights where, I can imagine nerve is super present though). A good ice hockey player needs to be basically average in everything! (you may be as felxible as a table, it won't matter much)
#
#
# - Basketball : pretty low nerve and flexibility as well (but a bit higher), the rest are are quite high, highlighting agility. Nerve is not much needed but endurance adn durability are. So, for being a basketabll player you should be able to keep performing well for long periods of time and very agile.
#
#
# - Tennis : hand-eye coordination is the mot demanded ability for being a good tennis player. On the other hand, nerve is not demanded at all, it lies around a 3/10. A good palyer also have to be agile and have avobe average endurance.
#
#
# - Soccer : having agility as it core ability, speed and endurance are also very important, whereas nerve and strength are not that much important for this sport.
#
#
# - American football : durability is its main ability, you need to be able to perform very very well for a long period of time under high stress. The rest abilities lie around average, some higher than 6 and 7, some a little bit lower. Flexibility is not that much required and surprisingly hand-eye coordination either (as an ex-football player I can say that it depends a lot what position you play, some of them require a lot of hand-eye coordination, whereas other none at all).
#
#
# - Cycling: distance : endurance as it super main ability, a little bit above average strength and power, basically for all the leg work they do. Although they are skinny as a spaguetti, they need to have power and resistance in their legs.
#
#
# - Auto racing : neve, nerve, nerve!!! It is demanded almost at its highest, it is calificaed as a 9.88/10. This is pretty accurate, if you have ever whatched an F1 race, all the overtakes and how they risk at every curve down to the milimiter is breathtaking (yes I love F1 racing). For the rest of the abilities hand-eye coordination is highly demanded as well, even for driving in a city like Madrid you need to have high hand-eye coordination so imagine when you are going at 250 km/h... Analytical aptitude is needed, for the overtakes, analyze every inch.
#
#
# - Golf : above average analytical aptitude as well as hand-eye coordination. Just imagine triying to kick a ball as few times as possible with a golf club to get into a hole. That requieres being quite analytical and having coordination. The rest, except for the power (for some kicks you may want to do with the club) are low.

# %% [markdown]
# ## Once the abilities are explored we have clustered all the sports, to see the similitudes between certain sports

# %% [markdown]
# ![clusters.png](attachment:clusters.png)

# %% [markdown]
# - Cluster 0 has:
#     - low everything, everything below 3
#     - hanbd-eye coordination and analytical aptitude around 5
#
#
# - Cluster 1 has:
#     - endurance, strength power and speed medium
#     - the rest are low to pretty low
#
#
# - Cluster 2 has :
#     - medium to low everything
#     - felixibility a little bit higher, alomost medium
#     - high nerve
#
#
# - Cluster 3 has:
#     - everything lies around a medium average
#     - nerve and felixibility are low

# %% [markdown]
# - In cluster 0 we have the folowwing sports:
#     - Table Tennis, Golf, Equestrian, Archery, Curling ,Bowling, Shooting, Billiards, Fishing
#
#
# - In cluster 1 we have the following sports:
#     - Speed Skating, Figure Skating, Cycling: Distance, Cycling: Sprints, Skiing: Nordic, Track and Field: High Jump,
#        Track and Field: Long, Triple jumps, Swimming (all strokes): Distance, Track and Field: Sprints,Rowing,
#        Track and Field: Distance, Track and Field: Middle Distance, Weight-Lifting, Swimming (all strokes): Sprints,
#        Track and Field: Weights, Canoe/Kayak, Roller Skating
#
#
# - In cluster 2 we have the following sports:
#     - Gymnastics, Rodeo: Steer Wrestling, Track and Field: Pole Vault, Surfing, Skiing: Freestyle, Bobsledding/Luge,
#       Ski Jumping, Auto Racing, Diving, Skateboarding, Rodeo: Calf Roping, Rodeo: Bull/Bareback/Bronc Riding,
#       Water Skiing, Horse Racing, Cheerleading
#
#
# - In cluster 3 we have the following sports:
#      - Boxing, Ice Hockey, Football, Basketball, Wrestling, Martial Arts, Tennis, Baseball/Softball, Soccer, Skiing: Alpine,     Water Polo, Rugby, Lacrosse, Field Hockey, Volleyball, Racquetball/Squash, Fencing, Team Handball, Badminton

# %% [markdown]
# ![pca.png](attachment:pca.png)

# %% [markdown]
# This last graph represents the 'situation' of the clusters. What this means is how well aggreupated they are and how well separated one cluster is from another.
#
# As we can see cluster 0 and cluster 3 are well separated and defined, whereas cluster 1 and 2 lie somewhere in the same place but somehow the K-Means algorithm found something notorious to have this two clusters separated.
